# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('.\laptop_price.csv', encoding = 'windows - 1251', index_col = 'laptop_ID')

# %% [markdown]
# ## Задание 1

# %%
df.head(10
       )
# Out:
#           Company          Product   TypeName  Inches  \
# laptop_ID
# 1           Apple      MacBook Pro  Ultrabook    13.3
# 2           Apple      Macbook Air  Ultrabook    13.3
# 3              HP           250 G6   Notebook    15.6
# 4           Apple      MacBook Pro  Ultrabook    15.4
# 5           Apple      MacBook Pro  Ultrabook    13.3
# 6            Acer         Aspire 3   Notebook    15.6
# 7           Apple      MacBook Pro  Ultrabook    15.4
# 8           Apple      Macbook Air  Ultrabook    13.3
# 9            Asus  ZenBook UX430UN  Ultrabook    14.0
# 10           Acer          Swift 3  Ultrabook    14.0
#
#                              ScreenResolution                         Cpu  \
# laptop_ID
# 1          IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz
# 2                                    1440x900        Intel Core i5 1.8GHz
# 3                           Full HD 1920x1080  Intel Core i5 7200U 2.5GHz
# ...

# %% [markdown]
# ## Задание 2

# %%
df.info
# Out:
# <bound method DataFrame.info of           Company                              Product            TypeName  \
# laptop_ID
# 1           Apple                          MacBook Pro           Ultrabook
# 2           Apple                          Macbook Air           Ultrabook
# 3              HP                               250 G6            Notebook
# 4           Apple                          MacBook Pro           Ultrabook
# 5           Apple                          MacBook Pro           Ultrabook
# ...           ...                                  ...                 ...
# 1316       Lenovo                       Yoga 500-14ISK  2 in 1 Convertible
# 1317       Lenovo                       Yoga 900-13ISK  2 in 1 Convertible
# 1318       Lenovo                   IdeaPad 100S-14IBR            Notebook
# 1319           HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook
# 1320         Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1303 entries, 1 to 1320
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   Product           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price_euros       1303 non-null   float64
# dtypes: float64(2), object(10)
# memory usage: 132.3+ KB

# %%
df.isna().sum()
# Out:
# Company             0
# Product             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price_euros         0
# dtype: int64

# %%
df.describe(include = ['object'])
# Out:
#        Company Product  TypeName   ScreenResolution  \
# count     1303    1303      1303               1303
# unique      19     618         6                 40
# top       Dell  XPS 13  Notebook  Full HD 1920x1080
# freq       297      30       727                507
#
#                                Cpu   Ram     Memory                    Gpu  \
# count                         1303  1303       1303                   1303
# unique                         118     9         39                    110
# top     Intel Core i5 7200U 2.5GHz   8GB  256GB SSD  Intel HD Graphics 620
# freq                           190   619        412                    281
#
#              OpSys Weight
# count         1303   1303
# unique           9    179
# top     Windows 10  2.2kg
# freq          1072    121

# %% [markdown]
# ## Задание 3

# %%
df.columns
# Out:
# Index(['Company', 'Product', 'TypeName', 'Inches', 'ScreenResolution', 'Cpu',
#        'Ram', 'Memory', 'Gpu', 'OpSys', 'Weight', 'Price_euros'],
#       dtype='object')

# %%
df['Company'].value_counts() == df['Company'].value_counts().max()
# Out:
# Dell          True
# Lenovo        True
# HP           False
# Asus         False
# Acer         False
# MSI          False
# Toshiba      False
# Apple        False
# Samsung      False
# Razer        False
# Mediacom     False
# Microsoft    False
# Xiaomi       False
# Vero         False
# Chuwi        False
# Google       False
# Fujitsu      False
# LG           False
# Huawei       False
# Name: Company, dtype: bool

# %%
df[['Company', 'Price_euros']][df['Price_euros'] == df['Price_euros'].max()]
# Out:
#           Company  Price_euros
# laptop_ID
# 200         Razer       6099.0

# %% [markdown]
# Самый дорогой ноут

# %%
df[['Product', 'Price_euros', 'Company']][df['Price_euros'] == df['Price_euros'].max()]
# Out:
#              Product  Price_euros Company
# laptop_ID
# 200        Blade Pro       6099.0   Razer

# %%
df[df['Price_euros'] == df['Price_euros'].max()]
# Out:
#           Company    Product TypeName  Inches  \
# laptop_ID
# 200         Razer  Blade Pro   Gaming    17.3
#
#                               ScreenResolution                          Cpu  \
# laptop_ID
# 200        4K Ultra HD / Touchscreen 3840x2160  Intel Core i7 7820HK 2.9GHz
#
#             Ram   Memory                      Gpu       OpSys  Weight  \
# laptop_ID
# 200        32GB  1TB SSD  Nvidia GeForce GTX 1080  Windows 10  3.49kg
#
#            Price_euros
# laptop_ID
# 200             6099.0

# %%
df.sort_values('Price_euros', ascending = False).iloc[0]
# Out:
# Company                                           Razer
# Product                                       Blade Pro
# TypeName                                         Gaming
# Inches                                             17.3
# ScreenResolution    4K Ultra HD / Touchscreen 3840x2160
# Cpu                         Intel Core i7 7820HK 2.9GHz
# Ram                                                32GB
# Memory                                          1TB SSD
# Gpu                             Nvidia GeForce GTX 1080
# OpSys                                        Windows 10
# Weight                                           3.49kg
# Price_euros                                      6099.0
# Name: 200, dtype: object

# %%
df.columns
# Out:
# Index(['Company', 'Product', 'TypeName', 'Inches', 'ScreenResolution', 'Cpu',
#        'Ram', 'Memory', 'Gpu', 'OpSys', 'Weight', 'Price_euros'],
#       dtype='object')

# %%
df[['Company', 'TypeName', 'Inches', 'Price_euros']][df['Inches'] == df['Inches'].min()]
# Out:
#           Company            TypeName  Inches  Price_euros
# laptop_ID
# 51         Lenovo  2 in 1 Convertible    10.1       319.00
# 1097       Lenovo  2 in 1 Convertible    10.1       646.27
# 1129       Lenovo  2 in 1 Convertible    10.1       549.00
# 1141       Lenovo  2 in 1 Convertible    10.1       479.00

# %%
df[['Company', 'TypeName', 'Inches', 'Price_euros']] == df['Inches'].min()
# Out:
#            Company  TypeName  Inches  Price_euros
# laptop_ID
# 1            False     False   False        False
# 2            False     False   False        False
# 3            False     False   False        False
# 4            False     False   False        False
# 5            False     False   False        False
# ...            ...       ...     ...          ...
# 1316         False     False   False        False
# 1317         False     False   False        False
# 1318         False     False   False        False
# 1319         False     False   False        False
# 1320         False     False   False        False
#
# [1303 rows x 4 columns]

# %%
df_HP = df[df['Company'] == 'HP']
# Out:
#           Company                                  Product   TypeName  Inches  \
# laptop_ID
# 3              HP                                   250 G6   Notebook    15.6
# 11             HP                                   250 G6   Notebook    15.6
# 12             HP                                   250 G6   Notebook    15.6
# 23             HP                                   255 G6   Notebook    15.6
# 25             HP  15-BS101nv (i7-8550U/8GB/256GB/FHD/W10)  Ultrabook    15.6
# ...           ...                                      ...        ...     ...
# 1300           HP                         Stream 11-Y000na    Netbook    11.6
# 1305           HP      15-AC110nv (i7-6500U/6GB/1TB/Radeon   Notebook    15.6
# 1312           HP                      Pavilion 15-AW003nv   Notebook    15.6
# 1314           HP                         Stream 11-Y000na    Netbook    11.6
# 1319           HP      15-AC110nv (i7-6500U/6GB/1TB/Radeon   Notebook    15.6
#
# ...

# %%
df_HP[df_HP['Price_euros'] == df_HP['Price_euros'].max()]
# Out:
#           Company   Product     TypeName  Inches             ScreenResolution  \
# laptop_ID
# 758            HP  Zbook 17  Workstation    17.3  IPS Panel Full HD 1920x1080
#
#                                      Cpu   Ram     Memory  \
# laptop_ID
# 758        Intel Xeon E3-1535M v5 2.9GHz  16GB  256GB SSD
#
#                             Gpu      OpSys Weight  Price_euros
# laptop_ID
# 758        Nvidia Quadro M2000M  Windows 7    3kg       4389.0

# %%
df
# Out:
#           Company                              Product            TypeName  \
# laptop_ID
# 1           Apple                          MacBook Pro           Ultrabook
# 2           Apple                          Macbook Air           Ultrabook
# 3              HP                               250 G6            Notebook
# 4           Apple                          MacBook Pro           Ultrabook
# 5           Apple                          MacBook Pro           Ultrabook
# ...           ...                                  ...                 ...
# 1316       Lenovo                       Yoga 500-14ISK  2 in 1 Convertible
# 1317       Lenovo                       Yoga 900-13ISK  2 in 1 Convertible
# 1318       Lenovo                   IdeaPad 100S-14IBR            Notebook
# 1319           HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook
# 1320         Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook
#
# ...

# %%
ultra = df[df['TypeName'] == 'Ultrabook'].shape[0]
ultra
# Out:
# 196

# %%
ozu = df[df['TypeName'] == 'Ultrabook'][df['Ram'] == '8GB'].shape[0]
ozu
# Out:
# C:\Users\evgen\AppData\Local\Temp\ipykernel_21208\2876458858.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   ozu = df[df['TypeName'] == 'Ultrabook'][df['Ram'] == '8GB'].shape[0]
# 140

# %%
res = (ozu/ultra) * 100
res
# Out:
# 71.42857142857143
