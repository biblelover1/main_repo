# %% [markdown]
# На основе выбранных продуктов из первого вебинара, выберите 2 A/B-теста и составьте план эксперимента, чтобы избежать Peeking Problem
# Распишите, какие метрики и как вы будете анализировать

# %% [markdown]
# <!-- Проверка гипотезы: Если снизить стоимость платной подписки на 10%, это позволит увеличить количество подписок (конверсии в платную подписку) на 5%, т.к. она будет финансово более доступна пользователям -->
# 1. Расчет числа ежедневно активных пользователей (1 000 000)
# 2. Определение % пользователей на тест от общего трафика: 10 000
# 3. Расчет числа пользователей на группу
# ![Расчет числа пользователей на группу](HW7_1.png)
# 4. Проведение А/A теста (оценка сплита)
# 5. Расчет количества дней для теста
# <!-- traffic = 10000
# user_group = 1455
# user_all = user_group * 2
# days = traffic/user_all -->
# 6. Оценка результатов спустя необходимое количество дней (не ранее)
# 7. Проведение t-теста (a = 0.05; 1 - b = 0.8) на нахождение статистических отличий между группами:
#
# | Группа   |    А    |    В     |
# |----------|---------|----------|
# |   Users  |   1455  |   1455   |
# | Конверсии|   10    |    21    |
#
# ![t-test](HW7_2.png)
#
# 8. Завершение теста
